# %%
using Flux, CUDA, IterTools, JSON, Images, ImageTransformations, cuDNN, Random, DataLoaders, Zygote, Printf, Statistics, BSON
using Augmentor
using Flux: onehotbatch
using Flux: onecold
using Flux: crossentropy
using Flux: flatten
using Flux: trainable
using Flux: flatten
using Flux: params
using Flux: Optimise
# Flux and CUDA magically using multiprocessing on GPU!!!
# Out:
# ┌ Warning: You are using a non-official build of Julia. This may cause issues with CUDA.jl.
# │ Please consider using an official build from https://julialang.org/downloads/.
# └ @ CUDA ~/.julia/packages/CUDA/oymHm/src/initialization.jl:179

# %%
CUDA.allowscalar(false)

# %% [markdown]
# # Define directories
# ann_dir = "4_cryst/ann"
# img_dir = "4_cryst/img"
# train_img_dir = "train_final/img"
# train_ann_dir = "train_final/ann"
# val_img_dir = "val_final/img"
# val_ann_dir = "val_final/ann"
#
# # Create directories if they don’t already exist
# for dir in [train_img_dir, train_ann_dir, val_img_dir, val_ann_dir]
#     isdir(dir) || mkdir(dir)
# end
#
# # Get list of image files (.jpg or .png)
# img_files = filter(f -> endswith(f, ".jpg") || endswith(f, ".png"), readdir(img_dir))
#
# # Shuffle the image files
# Random.shuffle!(img_files)
#
# # Split into training (80%) and validation (20%) sets
# train_size = Int(floor(0.8 * length(img_files)))
# train_files = img_files[1:train_size]
# val_files = img_files[train_size+1:end]
#
# # Helper function to copy files
# function copy_files(files, img_src, ann_src, img_dest, ann_dest)
#     for f in files
#         src_img = joinpath(img_src, f)
#         dst_img = joinpath(img_dest, f)
#         cp(src_img, dst_img; force=true)
#
#         # Annotation file (e.g., "image.jpg.json")
#         ann_filename = f * ".json"
#         src_ann = joinpath(ann_src, ann_filename)
#         dst_ann = joinpath(ann_dest, ann_filename)
#
#         if isfile(src_ann)
#             cp(src_ann, dst_ann; force=true)
#         else
#             @warn "JSON annotation not found for $f (expected: $(ann_filename))"
#         end
#     end
# end
#
# # Copy files to train and val folders
# copy_files(train_files, img_dir, ann_dir, train_img_dir, train_ann_dir)
# copy_files(val_files, img_dir, ann_dir, val_img_dir, val_ann_dir)
#
# println("✅ Dataset split complete. Images and annotations copied.")
# println("🧪 Train: $(length(train_files)) images")
# println("🧪 Val:   $(length(val_files)) images")

# %%
# Define a function to extract image name and classTitle from a single JSON file
function extract_image_label(json_file::String)
    # Read and parse the JSON file
    json_data = JSON.parsefile(json_file)
    
    # Extract the image file name (e.g., imgname.png) by stripping the ".json" extension
    imgfile = split(basename(json_file), ".json")[1]
    
    # Extract the label(s) from the classTitle inside the objects array
    labels = [obj["classTitle"] for obj in json_data["objects"]]
    
    # Return a tuple of image file name and associated labels
    return imgfile, labels
end

# Directory where the JSON files are stored
#json_files = readdir("path/to/json/files", join=true)  # Specify the directory path
function appendY(json_files, target)
    for json_file in json_files
        imgfile, labels = extract_image_label(json_file)
        for label in labels
            #push!(target, (imgfile, label))  # Append the image and label as a tuple
            push!(target, label)
        end
    end
end
# Out:
# appendY (generic function with 1 method)

# %%
# Load file for x_train y_train, x_val y_val
train_dir_img = "train_final/img";
train_dir_ann = "train_final/ann";
val_dir_img = "val_final/img";
val_dir_ann = "val_final/ann";

# GPU ver
x_train = readdir(train_dir_img, join=true) |> gpu;
y_train = [] |> gpu;
x_val = readdir(val_dir_img, join=true) |> gpu;
y_val = [] |> gpu;

# CPU ver
x_train_cpu = readdir(train_dir_img, join=true);
y_train_cpu = [];
x_val_cpu = readdir(val_dir_img, join=true);
y_val_cpu = [];

# %%
# append the image and label as a tuple to y
# GPU version
println("append the image and label into y set with GPU approach")
@time result_y_train = appendY(readdir(train_dir_ann, join=true), y_train) |> gpu;
@time result_y_val = appendY(readdir(val_dir_ann, join=true), y_val) |> gpu;

# CPU version
println("append the image and label into y set with CPU approach")
@time appendY(readdir(train_dir_ann, join=true), y_train_cpu);
@time appendY(readdir(val_dir_ann, join=true), y_val_cpu);
# Out:
# append the image and label into y set with GPU approach
#   0.120185 seconds (240.93 k allocations: 12.255 MiB, 98.35% compilation time)
#   0.000521 seconds (6.99 k allocations: 450.766 KiB)
# append the image and label into y set with CPU approach
#   0.001733 seconds (28.27 k allocations: 1.781 MiB)
#   0.000509 seconds (6.99 k allocations: 450.422 KiB)

# %%
# Define augmentation pipeline
p = Either(
    3=>Augmentor.FlipX(),                        # Random horizontal flip
    2=>Augmentor.Rotate(-15:15),                     # Random rotation between -15 and +15 degrees
    1=>Augmentor.ShearX(-10:10),                 # Random shear in X direction
    2=>Augmentor.Zoom(0.9:0.1:1.1),              # Random zoom
    1=>NoOp()
)
# Out:
# Either (1 out of 5 operation(s)):
#   - 33.3% chance to: Flip the X axis
#   - 22.2% chance to: Rotate by θ ∈ -15:15 degree
#   - 11.1% chance to: ShearX by ϕ ∈ -10:10 degree
#   - 22.2% chance to: Zoom by I ∈ {0.9×0.9, 1.0×1.0, 1.1×1.1}
#   - 11.1% chance to: No operation

# %%
# Function to resize and load image data
function load_image_data(image_file::String, target_height::Int, target_width::Int)
    img = Images.load(image_file)  # Load the image from the file
    img_aug = augment(img, p)
    img_resized = imresize(img_aug, target_width, target_height)  # Resize the image to target size
    # Get the resized image's height, width, and channels
    height, width = size(img_resized)
    
    # Create an empty array to hold the image data (height x width x 3)
    img_data = Array{Float32}(undef, height, width, 3)
    
    # Convert each pixel into its RGB components and store them as Float32
    for i in 1:height
        for j in 1:width
            pixel = img_resized[i, j]  # Get the RGB value of the pixel
            img_data[i, j, 1] = Float32(pixel.r)  # Red channel
            img_data[i, j, 2] = Float32(pixel.g)  # Green channel
            img_data[i, j, 3] = Float32(pixel.b)  # Blue channel
        end
    end
    
    return img_data  # Return the resized image data as a 3D array
end

function make_minibatch(X, Y, idxs, target_height, target_width)
    # Assuming X is a list of image file paths (strings), and Y is the list of class labels
    X_batch = Array{Float32}(undef, target_height, target_width, 3, length(idxs)) # Prepare empty batch
    for i in 1:length(idxs)
        img = load_image_data(X[idxs[i]], target_height, target_width)  # Load the image using index
        X_batch[:, :, :, i] = img
    end
    
    # Y is the list of labels, convert the indices to one-hot encoding
    classes = unique(Y)  # or manually: ["stone", "grass", "tree", "water"]
    Y_batch = onehotbatch([Y[i] for i in idxs], classes)
    
    return (X_batch, Y_batch)
end
# Out:
# make_minibatch (generic function with 1 method)

# %%
batchsize = 128
target_height = 256  # Define the target image height
target_width = 256   # Define the target image width

mb_idxs = IterTools.partition(1:length(x_train), batchsize);
mb_idxs_cpu = IterTools.partition(1:length(x_train_cpu), batchsize);

# GPU ver
println("Make batch for train and val set with GPU approach")
@time train_set = [make_minibatch(x_train, y_train, i, target_height, target_width) for i in mb_idxs] |> gpu;
@time val_set = make_minibatch(x_val, y_val, 1:length(x_val), target_height, target_width) |> gpu;

# CPU ver
println("Make batch for train and val set with CPU approach")
@time train_set_cpu = [make_minibatch(x_train_cpu, y_train_cpu, i, target_height, target_width) for i in mb_idxs_cpu];
@time val_set_cpu  = make_minibatch(x_val_cpu, y_val_cpu, 1:length(x_val_cpu), target_height, target_width);
# Out:
# Make batch for train and val set with GPU approach
#   5.697684 seconds (67.27 M allocations: 2.821 GiB, 7.49% gc time, 0.59% compilation time)
#   1.455248 seconds (17.86 M allocations: 754.961 MiB, 3.71% gc time)
# Make batch for train and val set with CPU approach
#   5.698759 seconds (67.27 M allocations: 2.828 GiB, 6.86% gc time, 0.56% compilation time)
#   1.526302 seconds (17.86 M allocations: 761.359 MiB, 3.26% gc time)

# %%
# pass the train and val set to GPU (Save space for GPU)
x_train = cpu(x_train);
y_train = cpu(x_train);
x_val = cpu(x_val);
y_val = cpu(y_val);

# %%
@info typeof(train_set)
@info typeof(val_set)
@info typeof(train_set_cpu)
@info typeof(val_set_cpu)
# Out:
# [ Info: Vector{Tuple{CuArray{Float32, 4, CUDA.DeviceMemory}, OneHotArrays.OneHotMatrix{UInt32, CuArray{UInt32, 1, CUDA.DeviceMemory}}}}
# [ Info: Tuple{CuArray{Float32, 4, CUDA.DeviceMemory}, OneHotArrays.OneHotMatrix{UInt32, CuArray{UInt32, 1, CUDA.DeviceMemory}}}
# [ Info: Vector{Tuple{Array{Float32, 4}, OneHotArrays.OneHotMatrix{UInt32, Vector{UInt32}}}}
# [ Info: Tuple{Array{Float32, 4}, OneHotArrays.OneHotMatrix{UInt32, Vector{UInt32}}}

# %%
# model init
#labels = ["stone", "mineral", "gem", "mineral ore", "rock", "crystal"];
# GPU version
model = Chain(
    Conv((3, 3), 3 => 16, relu, pad=1),
    #BatchNorm(16),
    MaxPool((2, 2)),
    Conv((3, 3), 16 => 32, relu, pad=1),
    #BatchNorm(32),
    MaxPool((2, 2)),
    Conv((3, 3), 32 => 64, relu, pad=1),
    MaxPool((2, 2)),
    Conv((3, 3), 64 => 238, relu, pad=1),
    MaxPool((2, 2)),
    flatten,
    Dense(60928, 128, relu),
    Dense(128, 6),
    softmax
) |> gpu;

#CPU version
model_cpu = Chain(
    Conv((3, 3), 3 => 16, relu, pad=1),
    #BatchNorm(16),
    MaxPool((2, 2)),
    Conv((3, 3), 16 => 32, relu, pad=1),
    #BatchNorm(32),
    MaxPool((2, 2)),
    Conv((3, 3), 32 => 64, relu, pad=1),
    MaxPool((2, 2)),
    Conv((3, 3), 64 => 238, relu, pad=1),
    MaxPool((2, 2)),
    flatten,
    Dense(60928, 128, relu),
    Dense(128, 6),
    softmax
);

# %%
#### THE REQUIRE FUNCTION AND TUNNING :3
function loss(model, x, y)
    x_aug = x .+ 0.1f0 * gpu(randn(eltype(x), size(x)))
    y_hat = model(x_aug)
    return Flux.crossentropy(y_hat, y)
end

function loss_cpu(model_cpu, x, y)
    x_aug = x .+ 0.1f0 * randn(eltype(x), size(x))  # stays on CPU
    y_hat = model_cpu(x_aug)
    return Flux.crossentropy(y_hat, y)
end

accuracy(x, y) = mean(onecold(model(x)) .== onecold(y));

current_lr = 0.001;  # initial value
opt = Flux.setup(Adam(current_lr), model); # For GPU
opt_cpu = Flux.setup(Adam(current_lr), model_cpu); # For CPU
epochs = 100;

# %%
# RESET STAT
best_acc = 0.0;

# %%
# THIS USE TO LOAD THE MODEL
BSON.@load "CNNs_rock.bson" model #val_acc
#best_acc = val_acc;

# %%
#### GPU VERSION
# Initialize arrays to store metrics
train_losses = Float32[];
val_losses = Float32[];
train_accuracies = Float32[];
val_accuracies = Float32[];

last_improvement = 0;

#### THE TRAIN EPOCH
# Make sure our model is nicely precompiled before starting our training loop
Flux.throttle(1) do
    model(train_set[1][1])
end

@info("Beginning training loop...")
@time for epoch_idx in 1:epochs
    global best_acc, last_improvement
    shuffle!(train_set) # Shuffle the train dataset
    # Train for a single epoch
    Flux.train!(loss, model, train_set, opt)

    # Init the train and test (loss and acc)
    train_loss = 0.0;
    train_acc = 0.0;
    val_loss = 0.0;
    val_acc = 0.0;

    # Unpack validation set
    X_val, Y_val = val_set
    # Calculate accuracy:
    val_acc = accuracy(val_set...)
    val_loss = loss(model, X_val, Y_val)

    # Train over each batch in the train_set
    for (X_batch, Y_batch) in train_set
        # Ensure `X_batch` and `Y_batch` are in the correct format (already unpacked from tuple)
        train_loss = loss(model, X_batch, Y_batch)  # Calculate loss for this batch
        train_acc = accuracy(X_batch, Y_batch)      # Calculate accuracy for this batch
    end
    
    @info(@sprintf("[%d]: Epoch %d", epoch_idx, epoch_idx))
    
    @info(@sprintf("  Train loss: %.4f, Train accuracy: %.4f", train_loss, train_acc))
    @info(@sprintf("  Val loss: %.4f, Val accuracy: %.4f", val_loss, val_acc))
    @info(@sprintf("-------------------------------------------"))
    # Store metrics for later visualization
    push!(train_losses, train_loss)
    push!(val_losses, val_loss)
    push!(train_accuracies, train_acc)
    push!(val_accuracies, val_acc)
    
    # If our accuracy is good enough, quit out.
    if val_acc >= 0.999
        @info(" -> Early-exiting: We reached our target accuracy of 99.9%")
        break
    end

    # If this is the best accuracy we've seen so far, save the model out
    """
    if val_acc > best_acc
        @info(" -> New best accuracy! Saving model out to CNNs_rock.bson")
        BSON.@save "CNNs_rock.bson" model epoch_idx val_acc
        best_acc = val_acc
        last_improvement = epoch_idx
    end
    """

    # If we haven't seen improvement in 5 epochs, drop our learning rate:
    
    if epoch_idx - last_improvement >= 5
        current_lr /= 10  # track this in a variable
        @warn(" -> Dropping learning rate to $current_lr")
        opt = Flux.setup(Adam(current_lr), model)  # reinitialize optimizer
        train_last_improvement = epoch_idx
    end
    
    if epoch_idx - last_improvement >= 50
        @warn(" -> We're calling this converged.")
        break
    end
end
@warn("--END OF TRAINING--")
# Out:
# [ Info: Beginning training loop...
# [ Info: [1]: Epoch 1
# [ Info:   Train loss: 3.8574, Train accuracy: 0.5469
# [ Info:   Val loss: 1.8654, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# [ Info: [2]: Epoch 2
# [ Info:   Train loss: 1.3813, Train accuracy: 0.5469
# [ Info:   Val loss: 1.0079, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# [ Info: [3]: Epoch 3
# [ Info:   Train loss: 1.6411, Train accuracy: 0.1719
# [ Info:   Val loss: 1.6669, Val accuracy: 0.0294
# [ Info: -------------------------------------------
# [ Info: [4]: Epoch 4
# [ Info:   Train loss: 1.6761, Train accuracy: 0.1719
# [ Info:   Val loss: 1.7013, Val accuracy: 0.0294
# [ Info: -------------------------------------------
# [ Info: [5]: Epoch 5
# [ Info:   Train loss: 1.6604, Train accuracy: 0.1797
# [ Info:   Val loss: 1.6510, Val accuracy: 0.0882
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 0.0001
# └ @ Main In[77]:73
# [ Info: [6]: Epoch 6
# [ Info:   Train loss: 1.6244, Train accuracy: 0.5781
# [ Info:   Val loss: 1.5939, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0e-5
# └ @ Main In[77]:73
# [ Info: [7]: Epoch 7
# [ Info:   Train loss: 1.6204, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5873, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000002e-6
# └ @ Main In[77]:73
# [ Info: [8]: Epoch 8
# [ Info:   Train loss: 1.6202, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5869, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000002e-7
# └ @ Main In[77]:73
# [ Info: [9]: Epoch 9
# [ Info:   Train loss: 1.6200, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5866, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000002e-8
# └ @ Main In[77]:73
# [ Info: [10]: Epoch 10
# [ Info:   Train loss: 1.6201, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5862, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000003e-9
# └ @ Main In[77]:73
# [ Info: [11]: Epoch 11
# [ Info:   Train loss: 1.6201, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5869, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000003e-10
# └ @ Main In[77]:73
# [ Info: [12]: Epoch 12
# [ Info:   Train loss: 1.6200, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5866, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000003e-11
# └ @ Main In[77]:73
# [ Info: [13]: Epoch 13
# [ Info:   Train loss: 1.6202, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5871, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000002e-12
# └ @ Main In[77]:73
# [ Info: [14]: Epoch 14
# [ Info:   Train loss: 1.6201, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5866, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000002e-13
# └ @ Main In[77]:73
# [ Info: [15]: Epoch 15
# [ Info:   Train loss: 1.6200, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5868, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000002e-14
# └ @ Main In[77]:73
# [ Info: [16]: Epoch 16
# [ Info:   Train loss: 1.6201, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5870, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0e-15
# └ @ Main In[77]:73
# [ Info: [17]: Epoch 17
# [ Info:   Train loss: 1.6203, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5865, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000001e-16
# └ @ Main In[77]:73
# [ Info: [18]: Epoch 18
# [ Info:   Train loss: 1.6203, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5867, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0e-17
# └ @ Main In[77]:73
# [ Info: [19]: Epoch 19
# [ Info:   Train loss: 1.6201, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5867, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0e-18
# └ @ Main In[77]:73
# [ Info: [20]: Epoch 20
# [ Info:   Train loss: 1.6201, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5864, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000001e-19
# └ @ Main In[77]:73
# [ Info: [21]: Epoch 21
# [ Info:   Train loss: 1.6201, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5868, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000001e-20
# └ @ Main In[77]:73
# [ Info: [22]: Epoch 22
# [ Info:   Train loss: 1.6204, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5867, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000001e-21
# └ @ Main In[77]:73
# [ Info: [23]: Epoch 23
# [ Info:   Train loss: 1.6201, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5867, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0e-22
# └ @ Main In[77]:73
# [ Info: [24]: Epoch 24
# [ Info:   Train loss: 1.6200, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5865, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000001e-23
# └ @ Main In[77]:73
# [ Info: [25]: Epoch 25
# [ Info:   Train loss: 1.6202, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5866, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000001e-24
# └ @ Main In[77]:73
# [ Info: [26]: Epoch 26
# [ Info:   Train loss: 1.6202, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5866, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000002e-25
# └ @ Main In[77]:73
# [ Info: [27]: Epoch 27
# [ Info:   Train loss: 1.6201, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5869, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000002e-26
# └ @ Main In[77]:73
# [ Info: [28]: Epoch 28
# [ Info:   Train loss: 1.6203, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5863, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000002e-27
# └ @ Main In[77]:73
# [ Info: [29]: Epoch 29
# [ Info:   Train loss: 1.6201, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5867, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000002e-28
# └ @ Main In[77]:73
# [ Info: [30]: Epoch 30
# [ Info:   Train loss: 1.6201, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5866, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000002e-29
# └ @ Main In[77]:73
# [ Info: [31]: Epoch 31
# [ Info:   Train loss: 1.6202, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5869, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000003e-30
# └ @ Main In[77]:73
# [ Info: [32]: Epoch 32
# [ Info:   Train loss: 1.6202, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5869, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000003e-31
# └ @ Main In[77]:73
# [ Info: [33]: Epoch 33
# [ Info:   Train loss: 1.6201, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5866, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000003e-32
# └ @ Main In[77]:73
# [ Info: [34]: Epoch 34
# [ Info:   Train loss: 1.6201, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5867, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000004e-33
# └ @ Main In[77]:73
# [ Info: [35]: Epoch 35
# [ Info:   Train loss: 1.6200, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5868, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000004e-34
# └ @ Main In[77]:73
# [ Info: [36]: Epoch 36
# [ Info:   Train loss: 1.6202, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5866, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000004e-35
# └ @ Main In[77]:73
# [ Info: [37]: Epoch 37
# [ Info:   Train loss: 1.6202, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5866, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000004e-36
# └ @ Main In[77]:73
# [ Info: [38]: Epoch 38
# [ Info:   Train loss: 1.6200, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5867, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000005e-37
# └ @ Main In[77]:73
# [ Info: [39]: Epoch 39
# [ Info:   Train loss: 1.6203, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5864, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000005e-38
# └ @ Main In[77]:73
# [ Info: [40]: Epoch 40
# [ Info:   Train loss: 1.6201, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5868, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000004e-39
# └ @ Main In[77]:73
# [ Info: [41]: Epoch 41
# [ Info:   Train loss: 1.6202, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5865, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000003e-40
# └ @ Main In[77]:73
# [ Info: [42]: Epoch 42
# [ Info:   Train loss: 1.6201, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5872, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000004e-41
# └ @ Main In[77]:73
# [ Info: [43]: Epoch 43
# [ Info:   Train loss: 1.6201, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5867, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000004e-42
# └ @ Main In[77]:73
# [ Info: [44]: Epoch 44
# [ Info:   Train loss: 1.6201, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5868, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000003e-43
# └ @ Main In[77]:73
#  25.204586 seconds (1.24 M allocations: 10.672 GiB, 1.51% gc time, 0.39% compilation time: 84% of which was recompilation)
# [ Info: [45]: Epoch 45
# [ Info:   Train loss: 1.6200, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5867, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000003e-44
# └ @ Main In[77]:73
# [ Info: [46]: Epoch 46
# [ Info:   Train loss: 1.6203, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5866, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000003e-45
# └ @ Main In[77]:73
# [ Info: [47]: Epoch 47
# [ Info:   Train loss: 1.6201, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5868, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000002e-46
# └ @ Main In[77]:73
# [ Info: [48]: Epoch 48
# [ Info:   Train loss: 1.6201, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5865, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000002e-47
# └ @ Main In[77]:73
# [ Info: [49]: Epoch 49
# [ Info:   Train loss: 1.6201, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5868, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000003e-48
# └ @ Main In[77]:73
# [ Info: [50]: Epoch 50
# [ Info:   Train loss: 1.6203, Train accuracy: 0.5703
# [ Info:   Val loss: 1.5867, Val accuracy: 0.7941
# [ Info: -------------------------------------------
# ┌ Warning:  -> Dropping learning rate to 1.0000000000000003e-49
# └ @ Main In[77]:73
# ┌ Warning:  -> We're calling this converged.
# └ @ Main In[77]:79
# ┌ Warning: --END OF TRAINING--
# └ @ Main In[77]:83

# %%
##### CPU VERSION
# Initialize arrays to store metrics
train_losses = Float32[];
val_losses = Float32[];
train_accuracies = Float32[];
val_accuracies = Float32[];

last_improvement = 0;

#### THE TRAIN EPOCH
# Make sure our model is nicely precompiled before starting our training loop
model_cpu(train_set_cpu[1][1])

@info("Beginning training loop...")
@time for epoch_idx in 1:epochs
    global best_acc, last_improvement
    shuffle!(train_set_cpu) # Shuffle the train dataset
    # Train for a single epoch
    Flux.train!(loss_cpu, model_cpu, train_set_cpu, opt_cpu)
    # Init the train and test (loss and acc)
    train_loss = 0.0;
    train_acc = 0.0;
    val_loss = 0.0;
    val_acc = 0.0;

    # Unpack validation set
    X_val, Y_val = val_set_cpu
    # Calculate accuracy:
    val_acc = accuracy(val_set_cpu...)
    val_loss = loss_cpu(model_cpu, X_val, Y_val)

    # Train over each batch in the train_set
    for (X_batch, Y_batch) in train_set_cpu
        # Ensure `X_batch` and `Y_batch` are in the correct format (already unpacked from tuple)
        train_loss = loss_cpu(model_cpu, X_batch, Y_batch)  # Calculate loss for this batch
        train_acc = accuracy(X_batch, Y_batch)      # Calculate accuracy for this batch
    end
    println("hey")
    
    @info(@sprintf("[%d]: Epoch %d", epoch_idx, epoch_idx))
    
    @info(@sprintf("  Train loss: %.4f, Train accuracy: %.4f", train_loss, train_acc))
    @info(@sprintf("  Val loss: %.4f, Val accuracy: %.4f", val_loss, val_acc))
    @info(@sprintf("-------------------------------------------"))
    # Store metrics for later visualization
    push!(train_losses, train_loss)
    push!(val_losses, val_loss)
    push!(train_accuracies, train_acc)
    push!(val_accuracies, val_acc)
    
    # If our accuracy is good enough, quit out.
    if val_acc >= 0.999
        @info(" -> Early-exiting: We reached our target accuracy of 99.9%")
        break
    end

    # If this is the best accuracy we've seen so far, save the model out
    """
    if val_acc > best_acc
        @info(" -> New best accuracy! Saving model out to CNNs_rock.bson")
        BSON.@save "CNNs_rock.bson" model epoch_idx val_acc
        best_acc = val_acc
        last_improvement = epoch_idx
    end
    """

    # If we haven't seen improvement in 5 epochs, drop our learning rate:
    
    if epoch_idx - last_improvement >= 5
        current_lr /= 10  # track this in a variable
        @warn(" -> Dropping learning rate to $current_lr")
        opt_cpu = Flux.setup(Adam(current_lr), model_cpu)  # reinitialize optimizer
        train_last_improvement = epoch_idx
    end
    
    if epoch_idx - last_improvement >= 50
        @warn(" -> We're calling this converged.")
        break
    end
end
@warn("--END OF TRAINING--")
# Out:
# [ Info: Beginning training loop...
# MethodError: no method matching gemm!(::Val{false}, ::Val{false}, ::Int64, ::Int64, ::Int64, ::Float32, ::Ptr{Float32}, ::CuPtr{Float32}, ::Float32, ::Ptr{Float32})
# The function `gemm!` exists, but no method is defined for this combination of argument types.
#
# Closest candidates are:
#   gemm!(::Val, ::Val, ::Int64, ::Int64, ::Int64, ::Float32, ::Ptr{Float32}, ::Ptr{Float32}, ::Float32, ::Ptr{Float32})
#    @ NNlib ~/.julia/packages/NNlib/CGMj3/src/gemm.jl:35
#   gemm!(::Val, ::Val, ::Int64, ::Int64, ::Int64, ::ComplexF32, ::Ptr{ComplexF32}, ::Ptr{ComplexF32}, ::ComplexF32, ::Ptr{ComplexF32})
#    @ NNlib ~/.julia/packages/NNlib/CGMj3/src/gemm.jl:35
#   gemm!(::Val, ::Val, ::Int64, ::Int64, ::Int64, ::ComplexF64, ::Ptr{ComplexF64}, ::Ptr{ComplexF64}, ::ComplexF64, ::Ptr{ComplexF64})
#    @ NNlib ~/.julia/packages/NNlib/CGMj3/src/gemm.jl:35
#   ...
#
#
# Stacktrace:
#   [1] (::NNlib.var"#conv_part#635"{Array{Float32, 3}, Float32, Float32, SubArray{Float32, 5, Array{Float32, 5}, Tuple{Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, UnitRange{Int64}, Base.Slice{Base.OneTo{Int64}}}, false}, SubArray{Float32, 5, Array{Float32, 5}, Tuple{Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, UnitRange{Int64}, Base.Slice{Base.OneTo{Int64}}}, false}, CuArray{Float32, 5, CUDA.DeviceMemory}, DenseConvDims{3, 3, 3, 6, 3}, Int64, Int64, Int64})(task_n::Int64, part::UnitRange{Int64})
#     @ NNlib ~/.julia/packages/NNlib/CGMj3/src/impl/conv_im2col.jl:58
#   [2] conv_im2col!(y::SubArray{Float32, 5, Array{Float32, 5}, Tuple{Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, UnitRange{Int64}, Base.Slice{Base.OneTo{Int64}}}, false}, x::SubArray{Float32, 5, Array{Float32, 5}, Tuple{Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, UnitRange{Int64}, Base.Slice{Base.OneTo{Int64}}}, false}, w::CuArray{Float32, 5, CUDA.DeviceMemory}, cdims::DenseConvDims{3, 3, 3, 6, 3}; col::Array{Float32, 3}, alpha::Float32, beta::Float32, ntasks::Int64)
#     @ NNlib ~/.julia/packages/NNlib/CGMj3/src/impl/conv_im2col.jl:69
#   [3] conv_im2col!(y::SubArray{Float32, 5, Array{Float32, 5}, Tuple{Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, UnitRange{Int64}, Base.Slice{Base.OneTo{Int64}}}, false}, x::SubArray{Float32, 5, Array{Float32, 5}, Tuple{Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, Base.Slice{Base.OneTo{Int64}}, UnitRange{Int64}, Base.Slice{Base.OneTo{Int64}}}, false}, w::CuArray{Float32, 5, CUDA.DeviceMemory}, cdims::DenseConvDims{3, 3, 3, 6, 3})
#     @ NNlib ~/.julia/packages/NNlib/CGMj3/src/impl/conv_im2col.jl:23
#   [4] (::NNlib.var"#conv_group#295"{@Kwargs{}, Array{Float32, 5}, Array{Float32, 5}, CuArray{Float32, 5, CUDA.DeviceMemory}, DenseConvDims{3, 3, 3, 6, 3}})(xc::UnitRange{Int64}, wc::UnitRange{Int64})
#     @ NNlib ~/.julia/packages/NNlib/CGMj3/src/conv.jl:209
#   [5] conv!(out::Array{Float32, 5}, in1::Array{Float32, 5}, in2::CuArray{Float32, 5, CUDA.DeviceMemory}, cdims::DenseConvDims{3, 3, 3, 6, 3}; kwargs::@Kwargs{})
#     @ NNlib ~/.julia/packages/NNlib/CGMj3/src/conv.jl:218
#   [6] conv!
#     @ ~/.julia/packages/NNlib/CGMj3/src/conv.jl:185 [inlined]
#   [7] conv!(y::Array{Float32, 4}, x::Array{Float32, 4}, w::CuArray{Float32, 4, CUDA.DeviceMemory}, cdims::DenseConvDims{2, 2, 2, 4, 2}; kwargs::@Kwargs{})
#     @ NNlib ~/.julia/packages/NNlib/CGMj3/src/conv.jl:145
#   [8] conv!
#     @ ~/.julia/packages/NNlib/CGMj3/src/conv.jl:140 [inlined]
#   [9] conv(x::Array{Float32, 4}, w::CuArray{Float32, 4, CUDA.DeviceMemory}, cdims::DenseConvDims{2, 2, 2, 4, 2}; kwargs::@Kwargs{})
#     @ NNlib ~/.julia/packages/NNlib/CGMj3/src/conv.jl:88
#  [10] conv
#     @ ~/.julia/packages/NNlib/CGMj3/src/conv.jl:83 [inlined]
#  [11] (::Conv{2, 4, typeof(relu), CuArray{Float32, 4, CUDA.DeviceMemory}, CuArray{Float32, 1, CUDA.DeviceMemory}})(x::Array{Float32, 4})
#     @ Flux ~/.julia/packages/Flux/3711C/src/layers/conv.jl:198
#  [12] macro expansion
#     @ ~/.julia/packages/Flux/3711C/src/layers/basic.jl:68 [inlined]
#  [13] _applychain(layers::Tuple{Conv{2, 4, typeof(relu), CuArray{Float32, 4, CUDA.DeviceMemory}, CuArray{Float32, 1, CUDA.DeviceMemory}}, MaxPool{2, 4}, Conv{2, 4, typeof(relu), CuArray{Float32, 4, CUDA.DeviceMemory}, CuArray{Float32, 1, CUDA.DeviceMemory}}, MaxPool{2, 4}, Conv{2, 4, typeof(relu), CuArray{Float32, 4, CUDA.DeviceMemory}, CuArray{Float32, 1, CUDA.DeviceMemory}}, MaxPool{2, 4}, Conv{2, 4, typeof(relu), CuArray{Float32, 4, CUDA.DeviceMemory}, CuArray{Float32, 1, CUDA.DeviceMemory}}, MaxPool{2, 4}, typeof(flatten), Dense{typeof(relu), CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 1, CUDA.DeviceMemory}}, Dense{typeof(identity), CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 1, CUDA.DeviceMemory}}, typeof(softmax)}, x::Array{Float32, 4})
#     @ Flux ~/.julia/packages/Flux/3711C/src/layers/basic.jl:68
#  [14] (::Chain{Tuple{Conv{2, 4, typeof(relu), CuArray{Float32, 4, CUDA.DeviceMemory}, CuArray{Float32, 1, CUDA.DeviceMemory}}, MaxPool{2, 4}, Conv{2, 4, typeof(relu), CuArray{Float32, 4, CUDA.DeviceMemory}, CuArray{Float32, 1, CUDA.DeviceMemory}}, MaxPool{2, 4}, Conv{2, 4, typeof(relu), CuArray{Float32, 4, CUDA.DeviceMemory}, CuArray{Float32, 1, CUDA.DeviceMemory}}, MaxPool{2, 4}, Conv{2, 4, typeof(relu), CuArray{Float32, 4, CUDA.DeviceMemory}, CuArray{Float32, 1, CUDA.DeviceMemory}}, MaxPool{2, 4}, typeof(flatten), Dense{typeof(relu), CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 1, CUDA.DeviceMemory}}, Dense{typeof(identity), CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 1, CUDA.DeviceMemory}}, typeof(softmax)}})(x::Array{Float32, 4})
#     @ Flux ~/.julia/packages/Flux/3711C/src/layers/basic.jl:65
#  [15] accuracy(x::Array{Float32, 4}, y::OneHotArrays.OneHotMatrix{UInt32, Vector{UInt32}})
#     @ Main ./In[19]:14
#  [16] macro expansion
#     @ ./In[23]:29 [inlined]
#  [17] macro expansion
#     @ ./timing.jl:581 [inlined]
#  [18] top-level scope
#     @ ./In[23]:15

# %%
# MANUALLY SAVE THE MODEL
BSON.@save "CNNs_rock.bson" model

# %%
using PyPlot
# Out:
# [ Info: Precompiling PyPlot [d330b81b-6aea-500a-939a-2ce795aea3ee] (cache misses: incompatible header (2))

# %%
plot(1:length(train_losses), train_losses, label="Train Loss", color="blue", linewidth=2)
plot(1:length(val_losses), val_losses, label="Validation Loss", color="red", linewidth=2)

xlabel("Epoch")
ylabel("Loss")
title("Training and Validation Loss")  # <- moved here, not inside `plot()`
legend()
grid(true)
tight_layout()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
# Plotting Train and Validation Accuracy
plot(1:length(train_accuracies), train_accuracies, label="Train Accuracy", color=:green)
plot(1:length(val_accuracies), val_accuracies, label="Validation Accuracy", color=:orange)

xlabel("Epoch")
ylabel("Loss")
title("Training and Validation Accuracy")  # <- moved here, not inside `plot()`
legend()
grid(true)
tight_layout()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
